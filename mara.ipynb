# %%
import base64
# paste-and-run: recreates mara project on the VM = b'''...''' = base64.b64decode(data)('/content/mara.tar.gz', 'wb').write(raw)('wrote', len(raw), 'bytes')

# %%
# %cd /content
# !tar xzf mara.tar.gz
# !pip -q install "transformers>=4.44" datasets tokenizers peft accelerate bitsandbytes
import torch; print(torch.cuda.get_device_name(0), "| torch", torch.__version__)
# Out:
# /content
# tar (child): mara.tar.gz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now
# Tesla T4 | torch 2.11.0+cu128
